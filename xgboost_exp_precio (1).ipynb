# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2901adf9-1dea-46ee-aaa8-56ccc3954ed2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2901adf9-1dea-46ee-aaa8-56ccc3954ed2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datos= pd.read_excel('exportacion (2).xlsx')

# %%
datos.head()
# Out:
#                        Variedad             Marca Unidad  Cantidad_Mercaderia  \
# 0  ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN                 0.00
# 1  ACEITE DE OLIVA EXTRA VIRGEN  COMERCIALIZADORA     KN              9892.80
# 2  ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN                 0.00
# 3  ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN                 0.00
# 4               ACEITE DE OLIVA             MONTE     KN             52294.86
#
#      Precio  Cantidad_Bultos                      Bulto       Fob  \
# 0  4.896647         56.42409  CONTENEDOR DE 20 PIES DRY       0.0
# 1  6.000000          1.00000  CONTENEDOR DE 20 PIES DRY   62856.0
# 2  4.896647         56.42409  CONTENEDOR DE 20 PIES DRY       0.0
# 3  4.896647         56.42409  CONTENEDOR DE 20 PIES DRY       0.0
# 4  4.160000          1.00000  CONTENEDOR DE 20 PIES DRY  274904.8
#
#   Fecha_Aceptacion  Dia  Mes   Ano Pais_Destino Via_Transporte Clausula_Venta  \
# ...

# %%
# Convertir a un formato de datetime
from datetime import datetime
datos['Fecha_Aceptacion'] = pd.to_datetime(datos['Fecha_Aceptacion'])

# %%
datos = datos.set_index('Fecha_Aceptacion')
datos.index.asfreq = '15D'

# %%
datos
# Out:
#                                       Variedad             Marca Unidad  \
# Fecha_Aceptacion
# 2018-01-01        ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN
# 2018-01-02        ACEITE DE OLIVA EXTRA VIRGEN  COMERCIALIZADORA     KN
# 2018-01-03        ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN
# 2018-01-04        ACEITE DE OLIVA EXTRA VIRGEN            OLISUR     KN
# 2018-01-05                     ACEITE DE OLIVA             MONTE     KN
# ...                                        ...               ...    ...
# 2021-12-27        ACEITE DE OLIVA EXTRA VIRGEN             MONTE     KN
# 2021-12-28        ACEITE DE OLIVA EXTRA VIRGEN          OLIVARES     KN
# 2021-12-29        ACEITE DE OLIVA EXTRA VIRGEN          SIRACUSA     KN
# 2021-12-30        ACEITE DE OLIVA EXTRA VIRGEN          OLIVARES     KN
# 2021-12-31                     ACEITE DE OLIVA            OLISUR     KN
#
#                   Cantidad_Mercaderia    Precio  Cantidad_Bultos  \
# ...

# %%
import seaborn as sns

# %%
train=datos_modelo[datos.index<'01-01-2021']
test=datos_modelo[datos.index>='01-01-2021']

# %%
#test y train de precio
fig,ax=plt.subplots(figsize=(15,5))
train['Precio'].plot(ax=ax,label='Entrenamiento')
test['Precio'].plot(ax=ax,label='Prueba')
plt.show()

# %%
datos.columns
# Out:
# Index(['Variedad', 'Marca', 'Unidad', 'Cantidad_Mercaderia', 'Precio',
#        'Cantidad_Bultos', 'Bulto', 'Fob', 'Dia', 'Mes', 'Ano', 'Pais_Destino',
#        'Via_Transporte', 'Clausula_Venta', 'flete', 'seguro', 'cif'],
#       dtype='object')

# %%
datos['Precio'].hist()
datos['Precio'].describe()
# Out:
# count    1461.000000
# mean        4.895721
# std         1.402434
# min         0.010000
# 25%         4.500000
# 50%         4.896647
# 75%         4.896647
# max        19.702778
# Name: Precio, dtype: float64

# %%
datos['Variedad'].hist()
datos['Variedad'].describe()
# Out:
# count                             1461
# unique                               2
# top       ACEITE DE OLIVA EXTRA VIRGEN
# freq                              1178
# Name: Variedad, dtype: object

# %%
datos['Cantidad_Mercaderia'].hist()
datos['Cantidad_Mercaderia'].describe()
# Out:
# count      1461.000000
# mean      37922.047413
# std       76314.360158
# min           0.000000
# 25%           0.000000
# 50%         910.000000
# 75%       40370.000000
# max      669350.850000
# Name: Cantidad_Mercaderia, dtype: float64

# %%
datos.hist()
datos.describe()
# Out:
#        Cantidad_Mercaderia       Precio  Cantidad_Bultos           Fob  \
# count          1461.000000  1461.000000      1461.000000  1.461000e+03
# mean          37922.047413     4.895721        56.263844  1.613210e+05
# std           76314.360158     1.402434       234.729414  3.099228e+05
# min               0.000000     0.010000         1.000000  0.000000e+00
# 25%               0.000000     4.500000         3.000000  0.000000e+00
# 50%             910.000000     4.896647        24.000000  6.745830e+03
# 75%           40370.000000     4.896647        56.424090  1.830048e+05
# max          669350.850000    19.702778      2500.000000  3.156128e+06
#
#                Dia          Mes          Ano          flete       seguro  \
# count  1461.000000  1461.000000  1461.000000    1461.000000  1461.000000
# mean     15.729637     6.522930  2019.501711   10690.664813   824.056837
# std       8.803105     3.449884     1.119945    9351.943115   504.871802
# ...

# %%
datos= datos[['Variedad', 'Marca', 'Unidad', 'Cantidad_Mercaderia', 'Precio',
       'Cantidad_Bultos', 'Bulto', 'Fob', 'Dia', 'Mes', 'Ano', 'Pais_Destino',
       'Via_Transporte', 'Clausula_Venta', 'flete', 'seguro', 'cif']]
  

  # create dummy variables
datos_modelo=pd.get_dummies(datos)
datos_modelo.columns
# Out:
# Index(['Cantidad_Mercaderia', 'Precio', 'Cantidad_Bultos', 'Fob', 'Dia', 'Mes',
#        'Ano', 'flete', 'seguro', 'cif', 'Variedad_ACEITE DE OLIVA',
#        'Variedad_ACEITE DE OLIVA EXTRA VIRGEN', 'Marca_AGRORESERVAS',
#        'Marca_ALONSO', 'Marca_COMERCIALIZADORA', 'Marca_DE PRADO',
#        'Marca_DELEYDA', 'Marca_DON ALBERTO', 'Marca_LAN',
#        'Marca_LAS DOSCIENTAS', 'Marca_MONTE', 'Marca_OLISUR',
#        'Marca_OLIVAMARCHIGUE', 'Marca_OLIVARES', 'Marca_OLIVOS',
#        'Marca_RAZETO', 'Marca_SIRACUSA', 'Marca_SOHO', 'Marca_VALLE',
#        'Unidad_KN', 'Bulto_CAJAS DE CARTON', 'Bulto_CONTENEDOR DE 20 PIES DRY',
#        'Bulto_CONTENEDOR DE 40 PIES DRY', 'Bulto_NO ESPECIFICA',
#        'Bulto_PALLETS', 'Pais_Destino_ALEMANIA', 'Pais_Destino_ARGENTINA',
#        'Pais_Destino_AUSTRALIA', 'Pais_Destino_BELGICA',
#        'Pais_Destino_BOLIVIA', 'Pais_Destino_BRASIL', 'Pais_Destino_CANADA',
#        'Pais_Destino_CHINA', 'Pais_Destino_COLOMBIA',
# ...

# %%
datos_modelo.head
# Out:
# <bound method NDFrame.head of                   Cantidad_Mercaderia    Precio  Cantidad_Bultos         Fob  \
# Fecha_Aceptacion
# 2018-01-01                       0.00  4.896647         56.42409        0.00
# 2018-01-02                    9892.80  6.000000          1.00000    62856.00
# 2018-01-03                       0.00  4.896647         56.42409        0.00
# 2018-01-04                       0.00  4.896647         56.42409        0.00
# 2018-01-05                   52294.86  4.160000          1.00000   274904.80
# ...                               ...       ...              ...         ...
# 2021-12-27                  144160.00  3.900000          1.00000   574242.00
# 2021-12-28                   62900.09  4.000000          1.00000   261538.40
# 2021-12-29                   46687.00  3.950000          2.00000   176803.99
# 2021-12-30                   72268.16  4.000000          1.00000   305792.16
# 2021-12-31                  378683.10  4.380000         24.00000  1793434.91
# ...

# %%
FEATURES=['Cantidad_Mercaderia', 'Cantidad_Bultos', 'Fob', 'Dia', 'Mes',
       'Ano', 'flete', 'seguro', 'cif', 'Variedad_ACEITE DE OLIVA',
       'Variedad_ACEITE DE OLIVA EXTRA VIRGEN', 'Marca_AGRORESERVAS',
       'Marca_ALONSO', 'Marca_COMERCIALIZADORA', 'Marca_DE PRADO',
       'Marca_DELEYDA', 'Marca_DON ALBERTO', 'Marca_LAN',
       'Marca_LAS DOSCIENTAS', 'Marca_MONTE', 'Marca_OLISUR',
       'Marca_OLIVAMARCHIGUE', 'Marca_OLIVARES', 'Marca_OLIVOS',
       'Marca_RAZETO', 'Marca_SIRACUSA', 'Marca_SOHO', 'Marca_VALLE',
       'Unidad_KN', 'Bulto_CAJAS DE CARTON', 'Bulto_CONTENEDOR DE 20 PIES DRY',
       'Bulto_CONTENEDOR DE 40 PIES DRY', 'Bulto_NO ESPECIFICA',
       'Bulto_PALLETS', 'Pais_Destino_ALEMANIA', 'Pais_Destino_ARGENTINA',
       'Pais_Destino_AUSTRALIA', 'Pais_Destino_BELGICA',
       'Pais_Destino_BOLIVIA', 'Pais_Destino_BRASIL', 'Pais_Destino_CANADA',
       'Pais_Destino_CHINA', 'Pais_Destino_COLOMBIA',
       'Pais_Destino_COSTA RICA', 'Pais_Destino_CUBA',
       'Pais_Destino_DINAMARCA', 'Pais_Destino_ECUADOR', 'Pais_Destino_ESPANA',
       'Pais_Destino_HONG KONG', 'Pais_Destino_JAPON', 'Pais_Destino_LETONIA',
       'Pais_Destino_MEXICO', 'Pais_Destino_NUEVA ZELANDIA',
       'Pais_Destino_OTROS(PAIS DESCONOCIDO)', 'Pais_Destino_PANAMA',
       'Pais_Destino_PARAGUAY', 'Pais_Destino_PERU', 'Pais_Destino_PORTUGAL',
       'Pais_Destino_RUSIA', 'Pais_Destino_SUDAFRICA',
       'Pais_Destino_TAIWAN (FORMOSA)', 'Pais_Destino_TER.HOLAN.EN AM',
       'Pais_Destino_U.S.A.', 'Pais_Destino_URUGUAY', 'Pais_Destino_VENEZUELA',
       'Via_Transporte_AEREO', 'Via_Transporte_CARRETERO',
       'Via_Transporte_MARITIMO', 'Clausula_Venta_CIF', 'Clausula_Venta_CIP',
       'Clausula_Venta_CYF', 'Clausula_Venta_CYS', 'Clausula_Venta_EX-F',
       'Clausula_Venta_FCA', 'Clausula_Venta_FOB', 'Clausula_Venta_FOB-FR',
       'Clausula_Venta_OTRO']

TARGET='Precio'

# %%
X_train=train[FEATURES]
y_train=train[TARGET]

X_test=test[FEATURES]
y_test=test[TARGET]

# %%
import xgboost as xgb

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [22:44:18] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4.57614	validation_1-rmse:4.55559
# [100]	validation_0-rmse:1.93874	validation_1-rmse:2.00295
# [200]	validation_0-rmse:1.11372	validation_1-rmse:1.26783
# [300]	validation_0-rmse:0.87931	validation_1-rmse:1.13209
# [400]	validation_0-rmse:0.79646	validation_1-rmse:1.11260
# [424]	validation_0-rmse:0.78492	validation_1-rmse:1.11391
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
# ...

# %%
test['prediction']=reg.predict(X_test)

# %% [markdown]
# Predicción precio modelo 1

# %%
datos_modelo = datos_modelo.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = datos_modelo[['Precio']].plot(figsize=(15, 5))
datos_modelo['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Datos y Predicción Modelo 1')
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo['prediction'].describe()
# Out:
# count    365.000000
# mean       4.664751
# std        0.891012
# min        1.882509
# 25%        4.540092
# 50%        4.811506
# 75%        4.811506
# max       10.772377
# Name: prediction, dtype: float64

# %%
ax = datos_modelo.loc[(datos_modelo.index > '10-10-2020') & (datos_modelo.index < '30-12-2021')]['Precio'] \
    .plot(figsize=(15, 5), title='Modelo 1 XGBOOST Precio ')
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'] \
    .plot(style='-')
plt.legend(['Datos Reales','Prediccion'])
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'].describe()
# Out:
# count    362.000000
# mean       4.669462
# std        0.890697
# min        1.882509
# 25%        4.540092
# 50%        4.811506
# 75%        4.811506
# max       10.772377
# Name: prediction, dtype: float64

# %%
from sklearn import metrics
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def evaluacion_metrica(y_true, y_pred):
  print ('Evaluation metric results:-')
  print (f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'MAE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
evaluacion_metrica(test['Precio'], test['prediction'])
# Out:
# Evaluation metric results:-
# MSE is : 1.237136927681107
# MAE is : 1.237136927681107
# RMSE is : 1.112266572221384
# MAPE is : 9.280519940136998
# R2 is : 0.26955428000157244

# %% [markdown]
# Modelo 2 precio

# %%
train=datos_modelo[datos.index<'01-01-2021']
test=datos_modelo[datos.index>='01-01-2021']

# %%
#test y train de precio modelo 2
fig,ax=plt.subplots(figsize=(15,5))
train['Precio'].plot(ax=ax,label='Entrenamiento')
test['Precio'].plot(ax=ax,label='Prueba')
plt.show()

# %%
FEATURES=['Variedad_ACEITE DE OLIVA',
       'Variedad_ACEITE DE OLIVA EXTRA VIRGEN','Pais_Destino_ALEMANIA', 'Pais_Destino_ARGENTINA',
       'Pais_Destino_AUSTRALIA', 'Pais_Destino_BELGICA',
       'Pais_Destino_BOLIVIA', 'Pais_Destino_BRASIL', 'Pais_Destino_CANADA',
       'Pais_Destino_CHINA', 'Pais_Destino_COLOMBIA',
       'Pais_Destino_COSTA RICA', 'Pais_Destino_CUBA',
       'Pais_Destino_DINAMARCA', 'Pais_Destino_ECUADOR', 'Pais_Destino_ESPANA',
       'Pais_Destino_HONG KONG', 'Pais_Destino_JAPON', 'Pais_Destino_LETONIA',
       'Pais_Destino_MEXICO', 'Pais_Destino_NUEVA ZELANDIA',
       'Pais_Destino_OTROS(PAIS DESCONOCIDO)', 'Pais_Destino_PANAMA',
       'Pais_Destino_PARAGUAY', 'Pais_Destino_PERU', 'Pais_Destino_PORTUGAL',
       'Pais_Destino_RUSIA', 'Pais_Destino_SUDAFRICA',
       'Pais_Destino_TAIWAN (FORMOSA)', 'Pais_Destino_TER.HOLAN.EN AM',
       'Pais_Destino_U.S.A.', 'Pais_Destino_URUGUAY', 'Pais_Destino_VENEZUELA',
       'Via_Transporte_AEREO', 'Via_Transporte_CARRETERO',
       'Via_Transporte_MARITIMO']

TARGET='Precio'

# %%
X_train=train[FEATURES]
y_train=train[TARGET]

X_test=test[FEATURES]
y_test=test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=800,
                       early_stopping_rounds=50, 
                       objective='reg:linear', subsample=1,
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [23:06:21] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4.57652	validation_1-rmse:4.55468
# [100]	validation_0-rmse:2.01723	validation_1-rmse:1.95407
# [200]	validation_0-rmse:1.29940	validation_1-rmse:1.21127
# [300]	validation_0-rmse:1.14006	validation_1-rmse:1.07429
# [400]	validation_0-rmse:1.09960	validation_1-rmse:1.06113
# [488]	validation_0-rmse:1.08292	validation_1-rmse:1.06126
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
# ...

# %%
test['prediction']=reg.predict(X_test)

# %%
datos_modelo = datos_modelo.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = datos_modelo[['Precio']].plot(figsize=(15, 5))
datos_modelo['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Datos y Predicción Modelo 2')
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo['prediction'].describe()
# Out:
# count    365.000000
# mean       4.865494
# std        0.788121
# min        2.659593
# 25%        4.910586
# 50%        4.910586
# 75%        5.077943
# max       10.793047
# Name: prediction, dtype: float64

# %%
ax = datos_modelo.loc[(datos_modelo.index > '10-10-2020') & (datos_modelo.index < '30-12-2021')]['Precio'] \
    .plot(figsize=(15, 5), title='Modelo 2 XGBOOST Precio ')
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'] \
    .plot(style='-')
plt.legend(['Datos Reales','Prediccion'])
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'].describe()
# Out:
# count    362.000000
# mean       4.865984
# std        0.790919
# min        2.659593
# 25%        4.910586
# 50%        4.910586
# 75%        5.042087
# max       10.793047
# Name: prediction, dtype: float64

# %%
from sklearn import metrics
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def evaluacion_metrica(y_true, y_pred):
  print ('Evaluation metric results:-')
  print (f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'MAE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
evaluacion_metrica(test['Precio'], test['prediction'])
# Out:
# Evaluation metric results:-
# MSE is : 1.1238358049250543
# MAE is : 1.1238358049250543
# RMSE is : 1.0601112229030756
# MAPE is : 8.528046076676034
# R2 is : 0.3364509333439808

# %% [markdown]
# Modelo 3 precio (variables fob, cantidad mercaderia, dia , mes ,año)

# %%
train=datos_modelo[datos.index<'01-01-2021']
test=datos_modelo[datos.index>='01-01-2021']

# %%
#test y train de precio modelo 3
fig,ax=plt.subplots(figsize=(15,5))
train['Precio'].plot(ax=ax,label='Entrenamiento')
test['Precio'].plot(ax=ax,label='Prueba')
plt.show()

# %%
FEATURES=['Cantidad_Mercaderia', 'Fob', 'Dia', 'Mes',
       'Ano', 'cif']

TARGET='Precio'

# %%
X_train=train[FEATURES]
y_train=train[TARGET]

X_test=test[FEATURES]
y_test=test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=800,
                       early_stopping_rounds=50, 
                       objective='reg:linear', subsample=1,
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [23:07:11] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4.57610	validation_1-rmse:4.55546
# [100]	validation_0-rmse:1.95157	validation_1-rmse:1.99389
# [200]	validation_0-rmse:1.14581	validation_1-rmse:1.27199
# [300]	validation_0-rmse:0.93371	validation_1-rmse:1.12570
# [400]	validation_0-rmse:0.86474	validation_1-rmse:1.09123
# [500]	validation_0-rmse:0.82892	validation_1-rmse:1.08203
# [600]	validation_0-rmse:0.78992	validation_1-rmse:1.06471
# [700]	validation_0-rmse:0.75962	validation_1-rmse:1.05327
# [799]	validation_0-rmse:0.72647	validation_1-rmse:1.03918
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
# ...

# %%
test['prediction']=reg.predict(X_test)

# %%
datos_modelo = datos_modelo.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = datos_modelo[['Precio']].plot(figsize=(15, 5))
datos_modelo['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Datos y Predicción Modelo 3')
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo['prediction'].describe()
# Out:
# count    365.000000
# mean       4.765257
# std        0.882123
# min        2.649874
# 25%        4.379062
# 50%        4.902707
# 75%        4.925786
# max       11.242950
# Name: prediction, dtype: float64

# %%
ax = datos_modelo.loc[(datos_modelo.index > '10-10-2020') & (datos_modelo.index < '30-12-2021')]['Precio'] \
    .plot(figsize=(15, 5), title='Modelo 3 XGBOOST Precio ')
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'] \
    .plot(style='-')
plt.legend(['Datos Reales','Prediccion'])
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'].describe()
# Out:
# count    362.000000
# mean       4.772140
# std        0.880108
# min        2.649874
# 25%        4.386443
# 50%        4.903585
# 75%        4.925786
# max       11.242950
# Name: prediction, dtype: float64

# %%
from sklearn import metrics
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def evaluacion_metrica(y_true, y_pred):
  print ('Evaluation metric results:-')
  print (f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'MAE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
evaluacion_metrica(test['Precio'], test['prediction'])
# Out:
# Evaluation metric results:-
# MSE is : 1.0798906178475918
# MAE is : 1.0798906178475918
# RMSE is : 1.039177856696144
# MAPE is : 7.6458135251283545
# R2 is : 0.3623975954288563

# %% [markdown]
# MODELO 4 VARIABLE FEATURES: PAIS ORIGEN Y DESTINO, TARGET: PRECIO

# %%
train=datos_modelo[datos.index<'01-01-2021']
test=datos_modelo[datos.index>='01-01-2021']

# %%
#test y train de precio modelo 4
fig,ax=plt.subplots(figsize=(15,5))
train['Precio'].plot(ax=ax,label='Entrenamiento')
test['Precio'].plot(ax=ax,label='Prueba')
plt.show()

# %%
FEATURES=['Pais_Destino_ALEMANIA', 'Pais_Destino_ARGENTINA',
       'Pais_Destino_AUSTRALIA', 'Pais_Destino_BELGICA',
       'Pais_Destino_BOLIVIA', 'Pais_Destino_BRASIL', 'Pais_Destino_CANADA',
       'Pais_Destino_CHINA', 'Pais_Destino_COLOMBIA',
       'Pais_Destino_COSTA RICA', 'Pais_Destino_CUBA',
       'Pais_Destino_DINAMARCA', 'Pais_Destino_ECUADOR', 'Pais_Destino_ESPANA',
       'Pais_Destino_HONG KONG', 'Pais_Destino_JAPON', 'Pais_Destino_LETONIA',
       'Pais_Destino_MEXICO', 'Pais_Destino_NUEVA ZELANDIA',
       'Pais_Destino_OTROS(PAIS DESCONOCIDO)', 'Pais_Destino_PANAMA',
       'Pais_Destino_PARAGUAY', 'Pais_Destino_PERU', 'Pais_Destino_PORTUGAL',
       'Pais_Destino_RUSIA', 'Pais_Destino_SUDAFRICA',
       'Pais_Destino_TAIWAN (FORMOSA)', 'Pais_Destino_TER.HOLAN.EN AM',
       'Pais_Destino_U.S.A.', 'Pais_Destino_URUGUAY', 'Pais_Destino_VENEZUELA']

TARGET='Precio'

# %%
X_train=train[FEATURES]
y_train=train[TARGET]

X_test=test[FEATURES]
y_test=test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=800,
                       early_stopping_rounds=50, 
                       objective='reg:linear', subsample=1,
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [22:55:58] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4.57656	validation_1-rmse:4.55478
# [100]	validation_0-rmse:2.02490	validation_1-rmse:1.97072
# [200]	validation_0-rmse:1.32701	validation_1-rmse:1.25573
# [300]	validation_0-rmse:1.18278	validation_1-rmse:1.12465
# [400]	validation_0-rmse:1.14860	validation_1-rmse:1.10505
# [500]	validation_0-rmse:1.13464	validation_1-rmse:1.09797
# [600]	validation_0-rmse:1.12608	validation_1-rmse:1.09592
# [700]	validation_0-rmse:1.11991	validation_1-rmse:1.09520
# [799]	validation_0-rmse:1.11512	validation_1-rmse:1.09481
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
# ...

# %%
test['prediction']=reg.predict(X_test)

# %%
datos_modelo = datos_modelo.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = datos_modelo[['Precio']].plot(figsize=(15, 5))
datos_modelo['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Datos y Predicción Modelo 4')
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo['prediction'].describe()
# Out:
# count    365.000000
# mean       4.885077
# std        0.825243
# min        2.057940
# 25%        5.014656
# 50%        5.014656
# 75%        5.014656
# max       10.205507
# Name: prediction, dtype: float64

# %%
ax = datos_modelo.loc[(datos_modelo.index > '10-10-2020') & (datos_modelo.index < '30-12-2021')]['Precio'] \
    .plot(figsize=(15, 5), title='Modelo 4 XGBOOST Precio ')
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'] \
    .plot(style='-')
plt.legend(['Datos Reales','Prediccion'])
plt.xlabel('Fecha de aceptación')
plt.ylabel('Precio unitario USD/Kg')
plt.show()

# %%
datos_modelo.loc[(datos_modelo.index > '01-01-2021') & (datos_modelo.index < '30-12-2021')]['prediction'].describe()
# Out:
# count    362.000000
# mean       4.886596
# std        0.827512
# min        2.057940
# 25%        5.014656
# 50%        5.014656
# 75%        5.014656
# max       10.205507
# Name: prediction, dtype: float64

# %%
from sklearn import metrics
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def evaluacion_metrica(y_true, y_pred):
  print ('Evaluation metric results:-')
  print (f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'MAE is : {metrics.mean_squared_error(y_true, y_pred)}')
  print (f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
  print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
  print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
evaluacion_metrica(test['Precio'], test['prediction'])
# Out:
# Evaluation metric results:-
# MSE is : 1.1983407561492097
# MAE is : 1.1983407561492097
# RMSE is : 1.0946875152979547
# MAPE is : 9.770161572622783
# R2 is : 0.2924607965024718
